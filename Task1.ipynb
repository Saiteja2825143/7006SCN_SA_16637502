# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/anaconda3/lib/python3.13/site-packages (4.1.2)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /opt/anaconda3/lib/python3.13/site-packages (from pyspark) (0.10.9.9)

# %%
 # Initialize Spark session
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, hash
from pyspark.sql.functions import count, when

# %%
# Import SparkSession (main entry point to create Spark applications)
spark = SparkSession.builder \
    .appName("FraudDetection") \
    .master("local[2]") \
    .config("spark.driver.memory", "2g") \
    .config("spark.sql.shuffle.partitions", "2") \
    .config("spark.default.parallelism", "2") \
    .getOrCreate()
print("Spark Session Created Successfully")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/06/07 21:06:43 WARN Utils: Your hostname, Sais-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 10.223.134.171 instead (on interface en0)
# 26/06/07 21:06:43 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/07 21:06:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/07 21:06:44 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark Session Created Successfully

# %%
# Load the CSV dataset into a Spark DataFrame with header and automatic schema detection
df = spark.read.csv("/Users/saiteja/Documents/Assignment/dataset.csv", header=True, inferSchema=True)

# %%
# Display the dataset schema (column names and data types)
df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- book_id: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- date_added: string (nullable = true)
#  |-- date_updated: string (nullable = true)
#  |-- read_at: string (nullable = true)
#  |-- started_at: string (nullable = true)
#  |-- n_votes: string (nullable = true)
#  |-- n_comments: string (nullable = true)

# %%
# Show the first 20 rows of the dataset
df.show(20)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |             user_id|             book_id|           review_id|              rating|         review_text|          date_added|        date_updated|             read_at|          started_at|             n_votes|n_comments|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |8842281e1d1347389...|            24375664|5cd416f3efc3f944f...|                   5|Mind blowingly co...|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | The undulations ...| but I wouldn't h...| and I wouldn't h...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | But the moment w...| if the Dark Fore...|Fri Aug 25 13:55:...|Mon Oct 09 08:55:...|Sat Oct 07 00:00:...|Sat Aug 26 00:00:...|                  16|                   0|                NULL|                NULL|      NULL|
# |8842281e1d1347389...|            18245960|dfdbb7b0eb5a7e4c2...|                   5|This is a special...|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | It is a 2015 Hug...| and translated f...| which made it in...|               etc. |                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | It is a book abo...| and aliens. The ...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | But what would h...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | I did like how t...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | I loved this quo...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | ""In the long hi...| how many protons...|      even in nature| the destruction ...| through the deca...| a high-energy co...|Sun Jul 30 07:44:...|Wed Aug 30 00:00:...|Sat Aug 26 12:05:...|Tue Aug 15 13:23:...|        28|
# |8842281e1d1347389...|             6392944|5e212a62bced17b4d...|                   3|I haven't read a ...|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | One that struck ...| have a ex-milita...| and solve myster...|Mon Jul 24 02:48:...|Sun Jul 30 09:28:...|Tue Jul 25 00:00:...|Mon Jul 24 00:00:...|                   6|                   0|                NULL|      NULL|
# |8842281e1d1347389...|            22078596|fdd13cad0695656be...|                   4|Fun, fast paced, ...|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | I enjoyed learni...|                oils| etc) was very in...|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | This was a dark ...|Mon Jul 24 02:33:...|Sun Jul 30 10:23:...|Sun Jul 30 15:42:...|Tue Jul 25 00:00:...|                  22|                   4|                NULL|                NULL|                NULL|      NULL|
# |8842281e1d1347389...|             6644782|bd0df91c9d918c0e4...|                   4|A fun book that g...|Mon Jul 24 02:28:...|Thu Aug 24 00:07:...|Sat Aug 05 00:00:...|Sun Jul 30 00:00:...|                   8|         0|
# |8842281e1d1347389...|             1995421|7350a30a2f5c785b1...|                   0|Kevin highly reco...|Mon Mar 06 07:14:...|Mon Mar 06 07:15:...|                NULL|                NULL|                   4|         0|
# |8842281e1d1347389...|             9460786|fc24c814e34ec6da3...|                   4|Giving a high rat...|                NULL|                NULL|                NULL|                NULL|                NULL|      NULL|
# | The part of the ...| and they were cr...| and so they wond...| and happened to ...|     and he said yes| they should use ...| and then planted...| which is getting...|                NULL|                NULL|      NULL|
# | The book was pub...| so only partiall...|Tue Feb 28 17:52:...|Fri May 26 12:04:...|Fri May 26 15:17:...|Fri May 05 00:00:...|                  13|                   3|                NULL|                NULL|      NULL|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
# Import os module for file and directory operations
import os

# Specify the folder containing the CSV file(s)
# Initialize variable to store total file size
path = "/Users/saiteja/Documents/Assignment"
# Initialize variable to store total file size
totalSize = 0

# Calculate the total size of all CSV files in the directory
for file in os.listdir(path):
    if file.endswith(".csv"):
        totalSize += os.path.getsize(os.path.join(path, file))
# Display the total dataset size in megabytes
print("Total size in MB:", totalSize / (1024 * 1024))
# Count and display the total number of rows in the dataset
print("Total rows: ", df.count())
# Count and display the total number of columns in the dataset
print("Total Columns: ", len(df.columns))
# Out:
# Total size in MB: 13411.494633674622
# [Stage 3:=====================================================> (102 + 2) / 105]
# Total rows:  44818365
# Total Columns:  11
